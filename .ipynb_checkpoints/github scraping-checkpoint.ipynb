# %%
import requests

def get_commits(user, repo, token, per_page=100, page=1):
    url = f"https://api.github.com/repos/{user}/{repo}/commits"
    headers = {'Authorization': f'token {token}'}
    params = {'per_page': per_page, 'page': page}
    response = requests.get(url, headers=headers, params=params)
    commits = response.json()
    return commits

# Example usage

users_repos = [('Julia-Susser', 'chatGPT-impact-measurement')]
all_commits = []

for user, repo in users_repos:
    page = 1
    while True:
        commits = get_commits(user, repo, token, page=page)
        if not commits:
            break
        all_commits.extend(commits)
        page += 1

print(f'Total commits fetched: {len(all_commits)}')
# Out:
# Total commits fetched: 20

# %%
import requests
from datetime import datetime 

def search_repositories(query, token, per_page=10):
    url = "https://api.github.com/search/repositories"
    headers = {'Authorization': f'token {token}'}
    params = {'q': query, 'per_page': per_page}
    response = requests.get(url, headers=headers, params=params)
    return response.json()

def get_contributors(contributors_url, token):
    headers = {'Authorization': f'token {token}'}
    response = requests.get(contributors_url, headers=headers)
    return response.json()

def get_user_details(user_url, token):
    headers = {'Authorization': f'token {token}'}
    response = requests.get(user_url, headers=headers)
    return response.json()

def get_lines_of_code(repo_url, token, username):
    headers = {'Authorization': f'token {token}'}
    response = requests.get(repo_url, headers=headers)
    data = response.json()
    print(data)
    print("\n\n")
    if 'files' in data:
        for file in data['files']:
            if file['author']['login'] == username:
                return file['changes']  # or use file['additions'] + file['deletions'] for total changes
    return 0

# Example usage
query = 'university of pennsylvania "final-project"'

# Search for repositories
repositories = search_repositories(query, token)


# Collect contributors and their timestamps
users = []
for repo in repositories.get('items', []):
    contributors_url = repo['contributors_url']
    contributors = get_contributors(contributors_url, token)
    timestamp = datetime.strptime(repo['updated_at'], "%Y-%m-%dT%H:%M:%SZ")  # Convert timestamp to datetime object
    for contributor in contributors:
        print(contributor)
        users.append({'contributor': contributor["login"], 'timestamp': timestamp})
print(users)
# Out:
# {'login': 'HuYuxin', 'id': 6688900, 'node_id': 'MDQ6VXNlcjY2ODg5MDA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6688900?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/HuYuxin', 'html_url': 'https://github.com/HuYuxin', 'followers_url': 'https://api.github.com/users/HuYuxin/followers', 'following_url': 'https://api.github.com/users/HuYuxin/following{/other_user}', 'gists_url': 'https://api.github.com/users/HuYuxin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/HuYuxin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/HuYuxin/subscriptions', 'organizations_url': 'https://api.github.com/users/HuYuxin/orgs', 'repos_url': 'https://api.github.com/users/HuYuxin/repos', 'events_url': 'https://api.github.com/users/HuYuxin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/HuYuxin/received_events', 'type': 'User', 'site_admin': False, 'contributions': 47}
# {'login': 'akhabbaz', 'id': 11495237, 'node_id': 'MDQ6VXNlcjExNDk1MjM3', 'avatar_url': 'https://avatars.githubusercontent.com/u/11495237?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/akhabbaz', 'html_url': 'https://github.com/akhabbaz', 'followers_url': 'https://api.github.com/users/akhabbaz/followers', 'following_url': 'https://api.github.com/users/akhabbaz/following{/other_user}', 'gists_url': 'https://api.github.com/users/akhabbaz/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/akhabbaz/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/akhabbaz/subscriptions', 'organizations_url': 'https://api.github.com/users/akhabbaz/orgs', 'repos_url': 'https://api.github.com/users/akhabbaz/repos', 'events_url': 'https://api.github.com/users/akhabbaz/events{/privacy}', 'received_events_url': 'https://api.github.com/users/akhabbaz/received_events', 'type': 'User', 'site_admin': False, 'contributions': 25}
# {'login': 'cloman93', 'id': 3002737, 'node_id': 'MDQ6VXNlcjMwMDI3Mzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3002737?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cloman93', 'html_url': 'https://github.com/cloman93', 'followers_url': 'https://api.github.com/users/cloman93/followers', 'following_url': 'https://api.github.com/users/cloman93/following{/other_user}', 'gists_url': 'https://api.github.com/users/cloman93/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cloman93/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cloman93/subscriptions', 'organizations_url': 'https://api.github.com/users/cloman93/orgs', 'repos_url': 'https://api.github.com/users/cloman93/repos', 'events_url': 'https://api.github.com/users/cloman93/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cloman93/received_events', 'type': 'User', 'site_admin': False, 'contributions': 32}
# {'login': 'mark345', 'id': 10176669, 'node_id': 'MDQ6VXNlcjEwMTc2NjY5', 'avatar_url': 'https://avatars.githubusercontent.com/u/10176669?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mark345', 'html_url': 'https://github.com/mark345', 'followers_url': 'https://api.github.com/users/mark345/followers', 'following_url': 'https://api.github.com/users/mark345/following{/other_user}', 'gists_url': 'https://api.github.com/users/mark345/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mark345/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mark345/subscriptions', 'organizations_url': 'https://api.github.com/users/mark345/orgs', 'repos_url': 'https://api.github.com/users/mark345/repos', 'events_url': 'https://api.github.com/users/mark345/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mark345/received_events', 'type': 'User', 'site_admin': False, 'contributions': 24}
# {'login': 'aharelick', 'id': 3924168, 'node_id': 'MDQ6VXNlcjM5MjQxNjg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3924168?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aharelick', 'html_url': 'https://github.com/aharelick', 'followers_url': 'https://api.github.com/users/aharelick/followers', 'following_url': 'https://api.github.com/users/aharelick/following{/other_user}', 'gists_url': 'https://api.github.com/users/aharelick/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aharelick/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aharelick/subscriptions', 'organizations_url': 'https://api.github.com/users/aharelick/orgs', 'repos_url': 'https://api.github.com/users/aharelick/repos', 'events_url': 'https://api.github.com/users/aharelick/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aharelick/received_events', 'type': 'User', 'site_admin': False, 'contributions': 9}
# {'login': 'zhaozheng-shen', 'id': 41030463, 'node_id': 'MDQ6VXNlcjQxMDMwNDYz', 'avatar_url': 'https://avatars.githubusercontent.com/u/41030463?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/zhaozheng-shen', 'html_url': 'https://github.com/zhaozheng-shen', 'followers_url': 'https://api.github.com/users/zhaozheng-shen/followers', 'following_url': 'https://api.github.com/users/zhaozheng-shen/following{/other_user}', 'gists_url': 'https://api.github.com/users/zhaozheng-shen/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/zhaozheng-shen/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/zhaozheng-shen/subscriptions', 'organizations_url': 'https://api.github.com/users/zhaozheng-shen/orgs', 'repos_url': 'https://api.github.com/users/zhaozheng-shen/repos', 'events_url': 'https://api.github.com/users/zhaozheng-shen/events{/privacy}', 'received_events_url': 'https://api.github.com/users/zhaozheng-shen/received_events', 'type': 'User', 'site_admin': False, 'contributions': 1}
# {'login': 'zhaozheng-shen', 'id': 41030463, 'node_id': 'MDQ6VXNlcjQxMDMwNDYz', 'avatar_url': 'https://avatars.githubusercontent.com/u/41030463?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/zhaozheng-shen', 'html_url': 'https://github.com/zhaozheng-shen', 'followers_url': 'https://api.github.com/users/zhaozheng-shen/followers', 'following_url': 'https://api.github.com/users/zhaozheng-shen/following{/other_user}', 'gists_url': 'https://api.github.com/users/zhaozheng-shen/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/zhaozheng-shen/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/zhaozheng-shen/subscriptions', 'organizations_url': 'https://api.github.com/users/zhaozheng-shen/orgs', 'repos_url': 'https://api.github.com/users/zhaozheng-shen/repos', 'events_url': 'https://api.github.com/users/zhaozheng-shen/events{/privacy}', 'received_events_url': 'https://api.github.com/users/zhaozheng-shen/received_events', 'type': 'User', 'site_admin': False, 'contributions': 2}
# {'login': 'lingbinc', 'id': 3270707, 'node_id': 'MDQ6VXNlcjMyNzA3MDc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3270707?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lingbinc', 'html_url': 'https://github.com/lingbinc', 'followers_url': 'https://api.github.com/users/lingbinc/followers', 'following_url': 'https://api.github.com/users/lingbinc/following{/other_user}', 'gists_url': 'https://api.github.com/users/lingbinc/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lingbinc/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lingbinc/subscriptions', 'organizations_url': 'https://api.github.com/users/lingbinc/orgs', 'repos_url': 'https://api.github.com/users/lingbinc/repos', 'events_url': 'https://api.github.com/users/lingbinc/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lingbinc/received_events', 'type': 'User', 'site_admin': False, 'contributions': 49}
# {'login': 'socrl', 'id': 6901745, 'node_id': 'MDQ6VXNlcjY5MDE3NDU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6901745?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/socrl', 'html_url': 'https://github.com/socrl', 'followers_url': 'https://api.github.com/users/socrl/followers', 'following_url': 'https://api.github.com/users/socrl/following{/other_user}', 'gists_url': 'https://api.github.com/users/socrl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/socrl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/socrl/subscriptions', 'organizations_url': 'https://api.github.com/users/socrl/orgs', 'repos_url': 'https://api.github.com/users/socrl/repos', 'events_url': 'https://api.github.com/users/socrl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/socrl/received_events', 'type': 'User', 'site_admin': False, 'contributions': 40}
# {'login': 'kathyxchen', 'id': 6656754, 'node_id': 'MDQ6VXNlcjY2NTY3NTQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6656754?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/kathyxchen', 'html_url': 'https://github.com/kathyxchen', 'followers_url': 'https://api.github.com/users/kathyxchen/followers', 'following_url': 'https://api.github.com/users/kathyxchen/following{/other_user}', 'gists_url': 'https://api.github.com/users/kathyxchen/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/kathyxchen/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/kathyxchen/subscriptions', 'organizations_url': 'https://api.github.com/users/kathyxchen/orgs', 'repos_url': 'https://api.github.com/users/kathyxchen/repos', 'events_url': 'https://api.github.com/users/kathyxchen/events{/privacy}', 'received_events_url': 'https://api.github.com/users/kathyxchen/received_events', 'type': 'User', 'site_admin': False, 'contributions': 22}
# {'login': 'yourdoraemon', 'id': 16690948, 'node_id': 'MDQ6VXNlcjE2NjkwOTQ4', 'avatar_url': 'https://avatars.githubusercontent.com/u/16690948?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/yourdoraemon', 'html_url': 'https://github.com/yourdoraemon', 'followers_url': 'https://api.github.com/users/yourdoraemon/followers', 'following_url': 'https://api.github.com/users/yourdoraemon/following{/other_user}', 'gists_url': 'https://api.github.com/users/yourdoraemon/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/yourdoraemon/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/yourdoraemon/subscriptions', 'organizations_url': 'https://api.github.com/users/yourdoraemon/orgs', 'repos_url': 'https://api.github.com/users/yourdoraemon/repos', 'events_url': 'https://api.github.com/users/yourdoraemon/events{/privacy}', 'received_events_url': 'https://api.github.com/users/yourdoraemon/received_events', 'type': 'User', 'site_admin': False, 'contributions': 12}
# {'login': 'haorshao', 'id': 18731806, 'node_id': 'MDQ6VXNlcjE4NzMxODA2', 'avatar_url': 'https://avatars.githubusercontent.com/u/18731806?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/haorshao', 'html_url': 'https://github.com/haorshao', 'followers_url': 'https://api.github.com/users/haorshao/followers', 'following_url': 'https://api.github.com/users/haorshao/following{/other_user}', 'gists_url': 'https://api.github.com/users/haorshao/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/haorshao/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/haorshao/subscriptions', 'organizations_url': 'https://api.github.com/users/haorshao/orgs', 'repos_url': 'https://api.github.com/users/haorshao/repos', 'events_url': 'https://api.github.com/users/haorshao/events{/privacy}', 'received_events_url': 'https://api.github.com/users/haorshao/received_events', 'type': 'User', 'site_admin': False, 'contributions': 11}
# {'login': 'Cathy-Cao7', 'id': 105680104, 'node_id': 'U_kgDOBkyM6A', 'avatar_url': 'https://avatars.githubusercontent.com/u/105680104?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Cathy-Cao7', 'html_url': 'https://github.com/Cathy-Cao7', 'followers_url': 'https://api.github.com/users/Cathy-Cao7/followers', 'following_url': 'https://api.github.com/users/Cathy-Cao7/following{/other_user}', 'gists_url': 'https://api.github.com/users/Cathy-Cao7/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Cathy-Cao7/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Cathy-Cao7/subscriptions', 'organizations_url': 'https://api.github.com/users/Cathy-Cao7/orgs', 'repos_url': 'https://api.github.com/users/Cathy-Cao7/repos', 'events_url': 'https://api.github.com/users/Cathy-Cao7/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Cathy-Cao7/received_events', 'type': 'User', 'site_admin': False, 'contributions': 15}
# {'login': 'blu666', 'id': 32961370, 'node_id': 'MDQ6VXNlcjMyOTYxMzcw', 'avatar_url': 'https://avatars.githubusercontent.com/u/32961370?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/blu666', 'html_url': 'https://github.com/blu666', 'followers_url': 'https://api.github.com/users/blu666/followers', 'following_url': 'https://api.github.com/users/blu666/following{/other_user}', 'gists_url': 'https://api.github.com/users/blu666/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/blu666/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/blu666/subscriptions', 'organizations_url': 'https://api.github.com/users/blu666/orgs', 'repos_url': 'https://api.github.com/users/blu666/repos', 'events_url': 'https://api.github.com/users/blu666/events{/privacy}', 'received_events_url': 'https://api.github.com/users/blu666/received_events', 'type': 'User', 'site_admin': False, 'contributions': 14}
# {'login': 'aharelick', 'id': 3924168, 'node_id': 'MDQ6VXNlcjM5MjQxNjg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3924168?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aharelick', 'html_url': 'https://github.com/aharelick', 'followers_url': 'https://api.github.com/users/aharelick/followers', 'following_url': 'https://api.github.com/users/aharelick/following{/other_user}', 'gists_url': 'https://api.github.com/users/aharelick/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aharelick/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aharelick/subscriptions', 'organizations_url': 'https://api.github.com/users/aharelick/orgs', 'repos_url': 'https://api.github.com/users/aharelick/repos', 'events_url': 'https://api.github.com/users/aharelick/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aharelick/received_events', 'type': 'User', 'site_admin': False, 'contributions': 7}
# {'login': 'jackg235', 'id': 41124102, 'node_id': 'MDQ6VXNlcjQxMTI0MTAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/41124102?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jackg235', 'html_url': 'https://github.com/jackg235', 'followers_url': 'https://api.github.com/users/jackg235/followers', 'following_url': 'https://api.github.com/users/jackg235/following{/other_user}', 'gists_url': 'https://api.github.com/users/jackg235/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jackg235/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jackg235/subscriptions', 'organizations_url': 'https://api.github.com/users/jackg235/orgs', 'repos_url': 'https://api.github.com/users/jackg235/repos', 'events_url': 'https://api.github.com/users/jackg235/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jackg235/received_events', 'type': 'User', 'site_admin': False, 'contributions': 4}
# {'login': 'versatran01', 'id': 1883423, 'node_id': 'MDQ6VXNlcjE4ODM0MjM=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1883423?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/versatran01', 'html_url': 'https://github.com/versatran01', 'followers_url': 'https://api.github.com/users/versatran01/followers', 'following_url': 'https://api.github.com/users/versatran01/following{/other_user}', 'gists_url': 'https://api.github.com/users/versatran01/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/versatran01/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/versatran01/subscriptions', 'organizations_url': 'https://api.github.com/users/versatran01/orgs', 'repos_url': 'https://api.github.com/users/versatran01/repos', 'events_url': 'https://api.github.com/users/versatran01/events{/privacy}', 'received_events_url': 'https://api.github.com/users/versatran01/received_events', 'type': 'User', 'site_admin': False, 'contributions': 8}
# {'login': 'GabriellaQiong', 'id': 3255407, 'node_id': 'MDQ6VXNlcjMyNTU0MDc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3255407?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/GabriellaQiong', 'html_url': 'https://github.com/GabriellaQiong', 'followers_url': 'https://api.github.com/users/GabriellaQiong/followers', 'following_url': 'https://api.github.com/users/GabriellaQiong/following{/other_user}', 'gists_url': 'https://api.github.com/users/GabriellaQiong/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/GabriellaQiong/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/GabriellaQiong/subscriptions', 'organizations_url': 'https://api.github.com/users/GabriellaQiong/orgs', 'repos_url': 'https://api.github.com/users/GabriellaQiong/repos', 'events_url': 'https://api.github.com/users/GabriellaQiong/events{/privacy}', 'received_events_url': 'https://api.github.com/users/GabriellaQiong/received_events', 'type': 'User', 'site_admin': False, 'contributions': 3}
# [{'contributor': 'HuYuxin', 'timestamp': datetime.datetime(2023, 1, 31, 8, 14, 22)}, {'contributor': 'akhabbaz', 'timestamp': datetime.datetime(2023, 1, 31, 8, 14, 22)}, {'contributor': 'cloman93', 'timestamp': datetime.datetime(2023, 9, 8, 12, 13, 49)}, {'contributor': 'mark345', 'timestamp': datetime.datetime(2023, 9, 8, 12, 13, 49)}, {'contributor': 'aharelick', 'timestamp': datetime.datetime(2023, 9, 8, 12, 13, 49)}, {'contributor': 'zhaozheng-shen', 'timestamp': datetime.datetime(2022, 1, 15, 22, 24, 1)}, {'contributor': 'zhaozheng-shen', 'timestamp': datetime.datetime(2022, 1, 15, 22, 24)}, {'contributor': 'lingbinc', 'timestamp': datetime.datetime(2022, 4, 25, 17, 13, 16)}, {'contributor': 'socrl', 'timestamp': datetime.datetime(2022, 4, 25, 17, 13, 16)}, {'contributor': 'kathyxchen', 'timestamp': datetime.datetime(2022, 4, 25, 17, 13, 16)}, {'contributor': 'yourdoraemon', 'timestamp': datetime.datetime(2016, 12, 1, 21, 0, 48)}, {'contributor': 'haorshao', 'timestamp': datetime.datetime(2016, 12, 1, 21, 0, 48)}, {'contributor': 'Cathy-Cao7', 'timestamp': datetime.datetime(2023, 11, 9, 23, 29, 24)}, {'contributor': 'blu666', 'timestamp': datetime.datetime(2023, 11, 9, 23, 29, 24)}, {'contributor': 'aharelick', 'timestamp': datetime.datetime(2015, 4, 23, 23, 33, 39)}, {'contributor': 'jackg235', 'timestamp': datetime.datetime(2019, 5, 28, 18, 25, 37)}, {'contributor': 'versatran01', 'timestamp': datetime.datetime(2014, 8, 2, 17, 53, 22)}, {'contributor': 'GabriellaQiong', 'timestamp': datetime.datetime(2014, 8, 2, 17, 53, 22)}]

# %%
import requests
from datetime import datetime, timedelta

def get_user_repositories(username, token):
    """ Fetch all repositories for a given user. """
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    response = requests.get(repos_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch repositories: {response.status_code}")
        return []

def filter_repositories_by_date(repositories, timestamp, years=5):
    """ Filter repositories created within four years of a specific timestamp. """
    start_date = timestamp - timedelta(days=365*years)
    end_date = timestamp + timedelta(days=365*years)
    filtered_repos = []
    for repo in repositories:
        repo_created_at = datetime.strptime(repo['created_at'], "%Y-%m-%dT%H:%M:%SZ")
        if start_date <= repo_created_at <= end_date:
            filtered_repos.append(repo)
    print(len(filtered_repos))
    return filtered_repos

def main(username, token, timestamp):
    repositories = get_user_repositories(username, token)
    filtered_repos = filter_repositories_by_date(repositories, timestamp)


for user in users:
    username = user["contributor"]  # Change to the username you want to check
    t = user["timestamp"]
    print(t)
    main(username, token, t)
# Out:
# 2023-01-31 08:14:22
# 11
# 2023-01-31 08:14:22
# 13
# 2023-09-08 12:13:49
# 0
# 2023-09-08 12:13:49
# 0
# 2023-09-08 12:13:49
# 1
# 2022-01-15 22:24:01
# 9
# 2022-01-15 22:24:00
# 9
# 2022-04-25 17:13:16
# 0
# 2022-04-25 17:13:16
# 0
# 2022-04-25 17:13:16
# 11
# 2016-12-01 21:00:48
# 5
# 2016-12-01 21:00:48
# 8
# 2023-11-09 23:29:24
# 5
# 2023-11-09 23:29:24
# 6
# 2015-04-23 23:33:39
# 16
# 2019-05-28 18:25:37
# 18
# 2014-08-02 17:53:22
# 11
# 2014-08-02 17:53:22
# 25

# %%
import requests
from datetime import datetime

def get_user_repositories(username, token):
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    response = requests.get(repos_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return []

def get_commits(repo_url, token, username, start_date, end_date):
    headers = {'Authorization': f'token {token}'}
    commits_url = f"{repo_url}/commits"
    params = {'author': username, "since":start_date,"until":end_date}
    response = requests.get(commits_url, headers=headers, params=params)
    commits = response.json()
    total_lines_added = 0
    number_of_commits = len(commits)
    for commit in commits:
        try:
            commit_url = commit["url"]
            headers = {'Authorization': f'token {token}'}
            response = requests.get(commit_url, headers=headers)
            commit_data = response.json()
            if commit_data and 'files' in commit_data:
                for file in commit_data['files']:
                    lines_added = file['additions']  
                    if lines_added > 10000:
                        number_of_commits = number_of_commits-1
                        continue
                    total_lines_added += lines_added
        except TypeError:
            continue
    
    return total_lines_added, number_of_commits


def get_info(username_to_check, start_date, end_date):
    lines_of_code_by_user = 0
    num_commits = 0
    repositories = get_user_repositories(username_to_check,token)
    for repo in repositories:
        repo_url = repo['url']
        l, n= get_commits(repo_url, token, username_to_check, start_date, end_date)
        lines_of_code_by_user += l
        num_commits += n
    if lines_of_code_by_user == 0:
        return 0
    print(f"Lines of code contributed by user '{username_to_check}' between {start_date} and {end_date}: {lines_of_code_by_user}")
    return lines_of_code_by_user / num_commits

t1 = "2021-11-30T00:00:00Z"
t2 = "2022-11-30T00:00:00Z"
t3 = "2023-11-30T00:00:00Z"
get_info("Sahish08", t1, t2)
get_info("Sahish08", t2, t3)
# Out:
# Lines of code contributed by user 'Sahish08' between 2021-11-30T00:00:00Z and 2022-11-30T00:00:00Z: 6260
# Lines of code contributed by user 'Sahish08' between 2022-11-30T00:00:00Z and 2023-11-30T00:00:00Z: 17209
# 2458.4285714285716

# %%
import requests

def get_trending_repositories(token):
    """Fetch a list of trending repositories on GitHub."""
    headers = {'Authorization': f'token {token}'}
    # Example URL for trending repositories; adjust query as needed
    url = "https://api.github.com/search/repositories?q=stars:>100&sort=stars&order=desc&per_page=10"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print(f"Failed to fetch repositories: {response.status_code}")
        return []

def get_recent_commit_users(repo, token, page):
    """Fetch recent commits from a repository and extract user data."""
    headers = {'Authorization': f'token {token}'}
    commits_url = repo['commits_url'].replace('{/sha}', '') + '?per_page=1000&page='+str(page)
    response = requests.get(commits_url, headers=headers)
    if response.status_code == 200:
        commits = response.json()
        users = {commit['author']['login'] for commit in commits if commit['author']}
        return list(users)
    else:
        print(f"Failed to fetch commits from {repo['name']}: {response.status_code}")
        return []

def main(token):
    trending_repos = get_trending_repositories(token)
    all_users = set()

    for repo in trending_repos:
        for page in range(5):
            users = get_recent_commit_users(repo, token, page)
            all_users.update(users)
            if len(all_users) >= 100:
                break

    return list(all_users)

# Example usage

users = main(token)
print(users)
# Out:
# ['spetterman66', 'ishuah', 'lakuapik', 'maehr', 'Xom', 'rahilsh', 'rickhanlonii', 'anastasiiauk', 'abhijeetsatpute', 'fabriziocucci', 'N-E-W-T-O-N', 'kunalg12', 'saurav-2104', 'dvanbrug', 'jenna5376', 'ahmaxed', 'hoxyq', 'AtomicVar', 'lzyzsd', 'bigfootjon', 'bulhaa', 'eshellman', 'Killpit', 'ahowe442', 'riderx', 'Re1nGer', 'karoliina', 'VivekGuruduttK28', 'waleedsadek-panx', 'Aryakoste', 'invalid-email-address', 'erwanvivien', 'reiscigit', 'manuelver', 'sellisd', 'PiousSutherland', 'lerignoux', 'Any97Cris', 'ZakaryaMeddahi', 'kianmeng', 'choznerol', 'matteocrippa', 'esmaeelE', 'web-padawan', 'WOLFRIEND', 'Aegwenia', 'JoseCutileiro', 'notpresident35', 'ruishawn', 'iamnafets', 'gikf', 'n0kovo', 'keyvank', 'AgrimPrasad', 'noebrito', 'angad-singhh', 'benzoms', 'villesundell', 'cclauss', 'xulunfan', 'frustr8dlec', '0Lola', 'the-jahid', 'Ronilpatil22', 'sujaldev', 'shiyujiucsb', 'nastaran-motiee', 'nacharya-msft', 'rickstaa', 'SlightDust', 'serima', 'Shubhamkashyap1601', 'alex-semenyuk', 'MartinZikmund', 'selvamuthukumaran1', 'ethan-id', 'ygdanchoi', 'Vojkan94', 'capjamesg', 'spuyet', 'gao-sun', 'farishan', 'matheusfelipeog', 'ilenia-magoni', 'ducdongmg', 'shootermv', 'ojeytonwilliams', 'zxc-w', 'mleers', 'haripajjuri', 'LarryRuane', '1jds', 'Delft-Open-Hardware', 'donnemartin', 'hwahyeon', '996icu', 'standardAI', 'jhordyess', 'kasvith', 'John-Richardson', 'mmatsumoto1026', 'nieldakarla', 'benjaminsehl', 'sharpcodex', 'byo-books', 'peteryao7', 'Mikey-Esteban', 'petitpandarouge', 'hallvaaw', 'prammmoe', 'KeyboardInterrupt', 'alexanderteno', 'samimwebdev', 'robandpdx', 'varshavjm', 'PedroRamos360', 'Deep512', 'hyperupcall', 'Harshdev098', 'msambol', 'huji405', 'andrewmchoward', 'brunoffsp', 'RGHANILOO', 'rscircus', 'friendlymatthew', 'panguncle', 'caroldinh', 'mostafaroshdy1', 'LiamSwayne', 'sarupbanskota', 'Wintus', 'ivaibhavraheja', 'srikanth-kandi', 'ivanxvasilev', 'karandeeppotato', 'nandita1', 'NaoCoding', 'UrakFerraz', 'dannyjung90', 'gpotter2', 'Morasiu', 'YikSanChan', 'LeonardoFurtado', 'ShaunSHamilton', 'acdlite', 'tomtau', 'omahs', 'inoue0426', 'iravitejakumar', 'lakshmi930', 'zairahira', 'caffeine-addictt', 'Yeah-Jack', 'markets', 'jdwilkin4', 'swati9star', 'Matthias84', 'pawelborkar', 'rajan-31', 'zolagonano', 'davorpa', 'Sboonny', 'gsathya', 'jupapios', 'AkashMani1', 'MlNl-PEKKA', 'hyperion912', 'antoniocoratelli', 'Edlan01', 'FayeNichols', 'aabouzaid', 'cy920820', 'ad-m', 'leontyr', 'satta', 'PlayCoder1024', 'virtualroot', 'Thenlie', 'eric-hc', 'sidemt', 'Nnachevvv', 'Bansnetsajak007', 'peiyuanix', 'morenoh149', 'LexGlu', 'jwasham', 'Mark-a-obrien', 'dependabot[bot]', 'trantienduchn', 'CodeMySky', 'maheshbohara', 'sohansai', 'loleg', 'scissorsneedfoodtoo', 'jbonta', 'Auxdible', 'yairhaimo', 'C-Alexis4414', 'A-4-Atom', 'huyenltnguyen', 'Supravisor', 'ericyangpan', 'AwesomeArunava', 'miyaliu666', 'SilverFlin', 'Ar-dst', 'hiscodesmells', 'EthanInSeattle', 'Karneades', 'zhangenming', 'Stitti', 'joewdavies', 'tomodachi94', 'kof-f', 'omair-muhammad', 'stevinz', 'aleixmorgadas', 'louisnguyencreative', 'hazanasec', 'markqian', 'sudhakar76', 'paescuj', 'neesara', 'dajiao007', 'savvycolleen', 'tecnotercio', 'yannbertrand', '0del', 'linhe0x0', 'xmakina', 'masaodev', 'steven2358', 'sujal0320', 'Buco7854', 'IgorLutiy', 'veerbhadrasolanki', 'abhinavkgrd', 'moT01', 'JeevaRamanathan', 'javache', 'htimsekim', 'Darkrider0007', 'sindresorhus', 'kevmo314', 'powerm17', 'dangiashish', 'ankita1964', 'devmuhib009', 'mananKoyawala', 'manaskarekar', 'catdevnull', 'jip2587', 'h3nk42', 'kareniel', 'blautista', 'M4ximumPizza', 'LIGMATV', 'fluency03', 'thoughtspile', 'eps1lon', 'htcrefactor', 'roannav', 'CinquinAndy', 'danieljl', '3xcpy', 'kevinxuv', 'brootware', 'kamranahmedse', 'vhladiienko', 'jatin-dua', 'mohdahsanrazakhan', 'hasanisaeed', 'ikayz', 'Unkn0wnCat', 'a2937', 'nuhmanpk', 'nekofar', 'RahulBirCodes', 'digvijaysinghh', 'PerryPal21', 'AhmedElTabarani', 'busolatom', 'stationname', 'Gokul2003g', 'zopagaduanjr', 'hhkaos', 'Cryo-Lord', 'cyrilb ...

# %%
import random as random
while True:
    user = random.choice(users)
    t1 = "2022-05-30T00:00:00Z"
    t2 = "2022-11-30T00:00:00Z"
    t3 = "2023-05-30T00:00:00Z"
    get_info(user, t1, t2)
    get_info(user, t2, t3)
# Out:
# Lines of code contributed by user 'villesundell' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 772
# Lines of code contributed by user 'villesundell' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 2
# Lines of code contributed by user 'sastofficial' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 384
# Lines of code contributed by user 'sastofficial' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 9930
# Lines of code contributed by user 'ethan-id' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 1
# Lines of code contributed by user 'ethan-id' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 222008
# Lines of code contributed by user 'ganesshkumar' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 104
# Lines of code contributed by user 'jwasham' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 4418
# Lines of code contributed by user 'jwasham' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 2516
# Lines of code contributed by user 'omahs' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 5
# Lines of code contributed by user 'riderx' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 7742
# Lines of code contributed by user 'riderx' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 2583
# Lines of code contributed by user 'Mark-a-obrien' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 4736
# Lines of code contributed by user 'Mark-a-obrien' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 1179
# Lines of code contributed by user 'ChetanNair' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 11275
# Lines of code contributed by user 'sujaldev' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 6384
# Lines of code contributed by user 'sujaldev' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 6017
# Lines of code contributed by user 'kunalg12' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 204
# Lines of code contributed by user 'kunalg12' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 310506
# Lines of code contributed by user 'rahilsh' between 2022-05-30T00:00:00Z and 2022-11-30T00:00:00Z: 1
# Lines of code contributed by user 'rahilsh' between 2022-11-30T00:00:00Z and 2023-05-30T00:00:00Z: 692
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[151], line 7
#       5 t2 = "2022-11-30T00:00:00Z"
#       6 t3 = "2023-05-30T00:00:00Z"
# ----> 7 get_info(user, t1, t2)
#       8 get_info(user, t2, t3)
#
# Cell In[140], line 46, in get_info(username_to_check, start_date, end_date)
#      44 for repo in repositories:
#      45     repo_url = repo['url']
# ---> 46     l, n= get_commits(repo_url, token, username_to_check, start_date, end_date)
#      47     lines_of_code_by_user += l
#      48     num_commits += n
#
# Cell In[140], line 25, in get_commits(repo_url, token, username, start_date, end_date)
#      23 commit_url = commit["url"]
#      24 headers = {'Authorization': f'token {token}'}
# ---> 25 response = requests.get(commit_url, headers=headers)
#      26 commit_data = response.json()
#      27 if commit_data and 'files' in commit_data:
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
